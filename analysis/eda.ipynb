# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('../processed_data/master_dataset.csv')

# %%
df
# Out:
#        Unnamed: 0 CountryName CountryCode        Date  C1_School closing  \
# 0               0       Aruba         ABW  2020-02-15                0.0
# 1               1       Aruba         ABW  2020-02-16                0.0
# 2               2       Aruba         ABW  2020-02-17                0.0
# 3               3       Aruba         ABW  2020-02-18                0.0
# 4               4       Aruba         ABW  2020-02-19                0.0
# ...           ...         ...         ...         ...                ...
# 10483       10483      Taiwan         TWN  2020-05-12                NaN
# 10484       10484      Taiwan         TWN  2020-05-13                NaN
# 10485       10485      Taiwan         TWN  2020-05-14                NaN
# 10486       10486      Taiwan         TWN  2020-05-15                NaN
# 10487       10487      Taiwan         TWN  2020-05-16                NaN
#
#        C1_Flag  C2_Workplace closing  C2_Flag  C3_Cancel public events  \
# ...
